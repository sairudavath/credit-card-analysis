# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



credit_card_data = pd.read_csv("credit card.csv")


def add_record():
    global credit_card_data
    customer_id = input("Enter the customer ID: ")
    surname = input("Enter the surname: ")
    credit_score = input("Enter the credit score: ")
    geography = input("Enter the geography: ")
    gender = input("Enter the gender: ")
    age = input("Enter the age: ")
    tenure = input("Enter the tenure: ")
    balance = input("Enter the balance: ")
    num_of_products = input("Enter the number of products: ")
    has_credit_card = input("Enter 1 if the customer has a credit card, 0 otherwise: ")
    is_active_member = input("Enter 1 if the customer is an active member, 0 otherwise: ")
    estimated_salary = input("Enter the estimated salary: ")
    exited           = input("Has the customer exited the bank? (0 for No, 1 for Yes): ")
    hashcard         = input("Does the customer have a credit card? (0 for No, 1 for Yes): ")
    
    max_row_num = credit_card_data["RowNumber"].max()
    new_record = pd.DataFrame({
            "RowNumber":[max_row_num + 1],
            "CustomerId": [customer_id],
            "Surname": [surname],
            "CreditScore": [credit_score],
            "Geography": [geography],
            "Gender": [gender],
            "Age": [age],
            "Tenure": [tenure],
            "Balance": [balance],
            "NumOfProducts": [num_of_products],
            "HasCrCard": [has_credit_card],
            "IsActiveMember": [is_active_member],
            "EstimatedSalary": [estimated_salary],
            "Exited":[exited],
            "HasCrCard":[hashcard]
    
    })
    



    credit_card_data = pd.concat([credit_card_data, new_record], ignore_index=True)
    credit_card_data.to_csv("credit card.csv", index=False)
    print("New record added successfully.")


def delete_record():
    customer_id = input("Enter the customer ID of the record to delete: ")
    record_index = credit_card_data.index[credit_card_data['CustomerId'] == int(customer_id)].tolist()

    if len(record_index) == 0:
        print("No record found with customer ID:", customer_id)
    else:
        credit_card_data.drop(record_index, inplace=True)
        credit_card_data.to_csv("credit card.csv", index=False)
        print("Record with customer ID", customer_id, "has been deleted.")


def display_menu():
    
    
    print("\\\\\\\\Credit Card Data Analysis Menu\\\\\\\\\\\\\\")
    
    print("1. Display the first 5 rows of data")
    print("2. Display the last 5 rows of data")
    print("3. Display the number of rows and columns")
    print("4. Display summary statistics")
    print("5. Filter data by a condition")
    print("6. Number of members who are eligible for credit card")
    print("7. Number of members who are eligible and active in the bank")
    print("8. Credit card users in Spain")
    print("9. Count the number of customers who have an estimated salary greater than 100000 and have also exited the bank")
    print("10. Select the age of persons belong to the France and have a creditscore of < 500")
    print("11. List customers with a credit score of 700 or higher, are active members, and have their balances sorted in descending order")
    print("12. Find the average balance of customers who exited the bank grouped by their geography:")
    print("13. Find the average estimated salary of all customers from France.")
    print("14. Find the top 10 customers with the highest estimated salary: .")
    print("15. Find the number of customersid and surname who have a credit score above 800 and a tenure of less than 3 years:.")
    print("16. Find all customers surname  who exited the bank and are from Germany.:.")
    print("17.Find all customers Id  who are female and have a credit score above 800:.")
    print("18.Find the balance  of customers from Spain who are between the ages of 25 and 40 :.")
    print("19.What is the list of customers who have a credit score of 700 or higher, are active members, and have their balances sorted in descending order:.")
    print("20. Find the number of customers who exited the bank grouped by their age::.")
    print("21. find the person with the lowest balance:.")
    print("22. Add a new record")
    print("23. Delete a record")
    print("24. Exit the program")
    choice = input("Enter your choice (1-24): ")
    return int(choice)




    
    
while True:
    
    # Ask the user for their username and password to validate their access
    admins = {
        "u": "p"
    }
    users = {
    "sai": "rudavath",
    "ganesh": "bodugu",
    "user3": "password3"
}


    
    role = input("Enter your role (Admin/User): ")
    if role.lower() == "admin":
        admin_username = input("Enter your username: ")
        admin_password = input("Enter your password: ")
        if admin_username in admins and admins[admin_username] == admin_password:
            print("Access granted! You are logged in as an admin.")
            

            
            action = input("Enter action (Add/Delete): ")
            
            
            if action.lower() == "add":
                
                customer_id = input("Enter the customer ID: ")
                surname = input("Enter the surname: ")
                credit_score = input("Enter the credit score: ")
                geography = input("Enter the geography: ")
                gender = input("Enter the gender: ")
                age = input("Enter the age: ")
                tenure = input("Enter the tenure: ")
                balance = input("Enter the balance: ")
                num_of_products = input("Enter the number of products: ")
                has_credit_card = input("Enter 1 if the customer has a credit card, 0 otherwise: ")
                is_active_member = input("Enter 1 if the customer is an active member, 0 otherwise: ")
                estimated_salary = input("Enter the estimated salary: ")
                exited           = input("Has the customer exited the bank? (0 for No, 1 for Yes): ")
                hashcard         = input("Does the customer have a credit card? (0 for No, 1 for Yes): ")
                

                max_row_num = credit_card_data["RowNumber"].max()
                new_record = pd.DataFrame({
                        "RowNumber":[max_row_num + 1],
                        "CustomerId": [customer_id],
                        "Surname": [surname],
                        "CreditScore": [credit_score],
                        "Geography": [geography],
                        "Gender": [gender],
                        "Age": [age],
                        "Tenure": [tenure],
                        "Balance": [balance],
                        "NumOfProducts": [num_of_products],
                        "HasCrCard": [has_credit_card],
                        "IsActiveMember": [is_active_member],
                        "EstimatedSalary": [estimated_salary],
                        "Exited":[exited],
                        "HasCrCard":[hashcard]

                })
                
                credit_card_data = pd.concat([credit_card_data, new_record], ignore_index=True)
                credit_card_data.to_csv("credit card.csv", index=False)
                print("New record added successfully.")

                
                # its working 
                
            elif action.lower() == "delete":
                 customer_id = input("Enter the customer ID of the record to delete: ")
            record_index = credit_card_data.index[credit_card_data['CustomerId'] == int(customer_id)].tolist()
            
                    

            if len(record_index) == 0:
                print("No record found with customer ID:", customer_id)
            else:
                credit_card_data.drop(record_index, inplace=True)
                credit_card_data.to_csv("credit card.csv", index=False)
                print("Record with customer ID", customer_id, "has been deleted.")


                    
                
            
        else:
            print("Access denied! Invalid username or password.")
            continue
            
            
    elif role.lower() == "user":
        user_username = input("Enter your username: ")
        user_password = input("Enter your password: ")
        if user_username in users and users[user_username] == user_password:
            print("Access granted! You are logged in as a user.")
            display_menu()
        else:
            print("Access denied! Invalid username or password.")
            continue
    else:
        print("Invalid role entered. Please try again.")
        continue

        
        
    choice = display_menu()

    if choice == 1:
        print(credit_card_data.head())
        continue
    elif choice == 2:
        print(credit_card_data.tail())
    elif choice == 3:
        print("Number of rows:", len(credit_card_data))
        print("Number of columns:", len(credit_card_data.columns))
    elif choice == 4:
        print(credit_card_data.describe())
    elif choice == 5:
        condition = input("Enter the filter condition (e.g., 'Balance > 5000'): ")
        filtered_data = credit_card_data.query(condition)
        print(filtered_data)

    elif choice == 6:
        eligible_members = credit_card_data.query("CreditScore > 700")

        # Count the number of eligible members for each credit score range
        count_by_score = eligible_members.groupby(pd.cut(eligible_members['CreditScore'], bins=[0, 500, 600, 700, 800, 900])).size()

        # Plot the results as a bar chart
        plt.bar(count_by_score.index.astype(str), count_by_score.values)
        plt.title("Number of Eligible Members by Credit Score Range")
        plt.xlabel("Credit Score Range")
        plt.ylabel("Number of Members")
        plt.show()

    elif choice == 7:
        

        # Query the credit card data for members who are active and have credit scores > 700
        active_eligible_members = credit_card_data.query("IsActiveMember == 1 and CreditScore > 700")

        # Count the number of active eligible members
        count_active_eligible = active_eligible_members["CreditScore"].count()

        # Count the number of inactive eligible members
        count_inactive_eligible = credit_card_data.query("IsActiveMember == 0 and CreditScore > 700")["CreditScore"].count()

        # Plot the results as a pie chart
        labels = ["Active Eligible Members", "Inactive Eligible Members"]
        sizes = [count_active_eligible, count_inactive_eligible]
        colors = ["green", "red"]
        plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
        plt.title("Proportion of Active vs Inactive Eligible Members")
        plt.show()
        
    elif choice == 8:
        

        # Query the credit card data for users in Spain
        users_in_spain = credit_card_data.query("Geography == 'Spain'")

        # Group the users in Spain by gender and count the number of users in each group
        users_by_gender = users_in_spain.groupby("Gender").size()

        # Plot the results as a bar chart
        plt.bar(users_by_gender.index, users_by_gender.values)
        plt.title("Number of Users in Spain by Gender")
        plt.xlabel("Gender")
        plt.ylabel("Number of Users")
        plt.show()

    elif choice == 9:
        # Filter the data
        selected_customers = credit_card_data.query("EstimatedSalary > 100000 and Exited == 1")[["CustomerId", "Surname"]]

        # Count the number of customers
        count = selected_customers.count()["CustomerId"]

        # Print the count
        print("Number of customers who have an estimated salary greater than 100000 and have also exited the bank:", count)

        # Plot the surnames and customer IDs
        plt.bar(selected_customers.index, selected_customers["CustomerId"])

        # Add labels and title
        plt.xlabel('Count')
        plt.ylabel('Surname and Customer ID')
        plt.title('Number of customers who have an estimated salary greater than 100000 and have also exited the bank')

        # Show the plot
        plt.show()

    elif choice == 10:
        selected_age = credit_card_data.query("Geography == 'France' and CreditScore < 500")["Age"]
        print("Selected age of persons belong to the France and have a creditscore of < 500:\n", selected_age)
        # Create a histogram
        plt.hist(selected_age, bins=10)

        # Add labels and title
        plt.xlabel('Age')
        plt.ylabel('Count')
        plt.title('Distribution of Ages')

        # Show the plot
        plt.show()

    elif choice == 11:
        selected_customers = credit_card_data.query("CreditScore >= 700 and IsActiveMember == 1").sort_values(by="Balance", ascending=False)
        selected_customers = selected_customers[["Surname", "Balance"]].reset_index(drop=True)
        plt.barh(y=selected_customers["Surname"], width=selected_customers["Balance"])
        plt.xlabel("Balance")
        plt.ylabel("Surname")
        plt.title("Balances of Customers with Credit Score >= 700 and Active Membership")
        plt.show()

        
    elif choice == 12:
        avg_balances_by_geo = credit_card_data.query("Exited == 1").groupby("Geography")["Balance"].mean()
        print("Average balance of customers who exited the bank grouped by their geography:\n", avg_balances_by_geo)
        
        x = np.linspace(-np.pi, np.pi, 100)
        y = np.cos(x)

        plt.plot(x, y)
        plt.xlabel('x')
        plt.ylabel('cos(x)')
        plt.title('Plot of Cosine Function')
        plt.show()
        
    elif choice == 13:
        
        avg_salary_france = credit_card_data.query("Geography == 'France'")["EstimatedSalary"].mean()
        print("Average estimated salary of all customers from France:", avg_salary_france)

        # create a histogram of estimated salaries for customers in France
        plt.hist(credit_card_data.query("Geography == 'France'")["EstimatedSalary"], bins=20)
        plt.title("Histogram of Estimated Salaries for Customers in France")
        plt.xlabel("Estimated Salary")
        plt.ylabel("Frequency")
        plt.show()
        
    elif choice == 14:
        top_10_highest_salary = credit_card_data.nlargest(10, "EstimatedSalary")[["CustomerId", "Surname", "EstimatedSalary"]]
        print("Top 10 customers with the highest estimated salary:\n", top_10_highest_salary)

        # create a bar chart of the top 10 customers with the highest estimated salary
        plt.bar(top_10_highest_salary["Surname"], top_10_highest_salary["EstimatedSalary"])
        plt.xticks(rotation=90)
        plt.xlabel("Surname")
        plt.ylabel("Estimated Salary")
        plt.title("Top 10 Customers with the Highest Estimated Salary")
        plt.show()

    elif choice == 15:
        selected_customers = credit_card_data.query("CreditScore > 800 and Tenure < 3")[["CustomerId", "Surname"]]
        print("Number of customersid and surname who have a credit score above 800 and a tenure of less than 3 years:\n", selected_customers)

        # create a scatter plot of credit score vs. tenure
        plt.scatter(credit_card_data.query("CreditScore > 800 and Tenure < 3")["CreditScore"], credit_card_data.query("CreditScore > 800 and Tenure < 3")["Tenure"])
        plt.xlabel("Credit Score")
        plt.ylabel("Tenure")
        plt.title("Credit Score vs. Tenure")
        plt.show()

    elif choice == 16:
        selected_surnames = credit_card_data.query("Exited == 1 and Geography == 'Germany'")["Surname"]
        print("Customers surname who exited the bank and are from Germany:\n", selected_surnames)

        # create a bar chart showing the number of customers from Germany who exited the bank
        num_exited_customers = len(selected_surnames)
        num_remaining_customers = len(credit_card_data.query("Geography == 'Germany'")) - num_exited_customers
        x = ["Exited Customers", "Remaining Customers"]
        y = [num_exited_customers, num_remaining_customers]
        plt.bar(x, y)
        plt.title("Number of Customers from Germany Who Exited the Bank")
        plt.show()

    elif choice == 17:
        selected_ids = credit_card_data.query("Gender == 'Female' and CreditScore > 800")["CustomerId"]
        print("Customers Id who are female and have a credit score above 800:\n", selected_ids)

        # create a pie chart showing the proportion of female customers with credit scores above 800 compared to the total number of female customers
        total_female_customers = len(credit_card_data.query("Gender == 'Female'"))
        selected_female_customers = len(selected_ids)
        labels = ["Selected Female Customers", "Other Female Customers"]
        sizes = [selected_female_customers, total_female_customers - selected_female_customers]
        plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
        plt.title("Proportion of Female Customers with Credit Scores Above 800")
        plt.axis('equal')
        plt.show()
    elif choice == 18:
        selected_balances = credit_card_data.query("Geography == 'Spain' and Age >= 25 and Age <= 40")["Balance"]
        print("Balance of customers from Spain who are between the ages of 25 and 40:\n", selected_balances)

        # create a histogram of selected balances
        plt.hist(selected_balances, bins=20)
        plt.xlabel("Balance")
        plt.ylabel("Count")
        plt.title("Histogram of balances for customers from Spain (ages 25-40)")
        plt.show()


    elif choice == 19:
        selected_customers = credit_card_data.query("CreditScore >= 700 and IsActiveMember == 1").sort_values(by="Balance", ascending=False)[["CustomerId", "Surname", "Balance"]]
        print("Customers with a credit score of 700 or higher, are active members, and have their balances sorted in descending order:\n", selected_customers.head(10))

        # create a bar chart of the top 10 customers with the highest balances
        top_customers = selected_customers.head(10)
        plt.bar(top_customers["Surname"], top_customers["Balance"])
        plt.xticks(rotation=90)
        plt.xlabel("Customer Surname")
        plt.ylabel("Balance")
        plt.title("Top 10 Customers with Highest Balances")
        plt.show()

    elif choice == 20:
        count_by_age = credit_card_data.query("Exited == 1").groupby("Age").count()["CustomerId"]
        count_by_age.plot(kind='bar', figsize=(15, 10), title="Number of customers who exited the bank by age")
        plt.xlabel("Age")
        plt.ylabel("Count of Customers")
        plt.show()
        
    elif choice == 21:
        
        min_balance = credit_card_data["Balance"].min()
        customer_with_min_balance = credit_card_data[credit_card_data["Balance"] == min_balance]["Surname"].values[0]
        print(f"The customer with the lowest balance is {customer_with_min_balance}.")
        print("The balance Hargrave has:", min_balance)

        # create a scatter plot of balance vs. limit
        plt.scatter(credit_card_data["Surname"], credit_card_data["Balance"])
        plt.xlabel("Credit limit")
        plt.ylabel("Balance")
        plt.title("Credit card balances vs. limits")
        plt.show()
        
    elif choice == 22:
        add_record()
    elif choice == 23:
        delete_record()
    elif choice == 24:
        print("Exiting program...")
        exit()
    else:
        print("Invalid choice. Please try again.")
